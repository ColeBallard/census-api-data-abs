# %%
import requests
import pandas as pd

# %%
state2019 = requests.get('https://api.census.gov/data/2018/abscs?get=NAME,GEO_ID,NAICS2017_LABEL,SEX,ETH_GROUP,RACE_GROUP,VET_GROUP,FIRMPDEMP&for=state:*&NAICS2017=00&key=a4bcb4614372e8f229066cbce694ccdb6b558ef4')

# %%
data=state2019.json()

# %%
companysummarystate2019 = pd.DataFrame (data[1:], columns= data[0])

# %%
companysummarystate2019
# Out:
#              NAME       GEO_ID        NAICS2017_LABEL  SEX ETH_GROUP  \
# 0     Mississippi  0400000US28  Total for all sectors  002       029
# 1     Mississippi  0400000US28  Total for all sectors  003       029
# 2     Mississippi  0400000US28  Total for all sectors  004       029
# 3     Mississippi  0400000US28  Total for all sectors  001       001
# 4     Mississippi  0400000US28  Total for all sectors  096       096
# ...           ...          ...                    ...  ...       ...
# 9663    Minnesota  0400000US27  Total for all sectors  002       029
# 9664    Minnesota  0400000US27  Total for all sectors  003       029
# 9665    Minnesota  0400000US27  Total for all sectors  004       029
# 9666    Minnesota  0400000US27  Total for all sectors  001       001
# 9667    Minnesota  0400000US27  Total for all sectors  096       096
#
#      RACE_GROUP VET_GROUP FIRMPDEMP NAICS2017 state
# 0            00       003         0        00    28
# ...
